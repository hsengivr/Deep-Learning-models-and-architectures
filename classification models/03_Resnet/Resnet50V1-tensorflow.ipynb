# %% [markdown]
# ### [ResNet50-V1](https://medium.com/@sharma.tanish096/detailed-explanation-of-residual-network-resnet50-cnn-model-106e0ab9fa9e)

# %% [markdown]
# #### Import libraries

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Dense, MaxPooling2D, GlobalAveragePooling2D, Activation, Add, BatchNormalization, ZeroPadding2D
from tensorflow.keras import Model

# %% [markdown]
# #### Conv_BN_Relu function

# %%
def conv_block(x, filters, kernel_size, strides, padding='same'):
  """
  Basic function defining sequential operations -> conv2d + BatchNorm + Relu

  x -> input layer
  """
  x = Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding=padding)(x)
  x = BatchNormalization()(x)
  x = Activation(activation='relu')(x)
  return x

# %% [markdown]
# #### Identity block

# %%
def identity_block(x, filters):
  """
  Used when input and output dimensions match

  [(1x1conv+BN+Relu -> 3x3conv+BN+Relu -> 1x1conv+BN) + x ] -> Relu
  """
  shortcut = x

  x = conv_block(x, filters, kernel_size=1, strides=1)
  x = conv_block(x, filters, kernel_size=3, strides=1)
  x = Conv2D(filters=filters*4, kernel_size=1)(x)
  x = BatchNormalization()(x)
  x = Add()([x, shortcut])
  x = Activation('relu')(x)
  return x

# %% [markdown]
# #### Convolutional/projection block

# %%
def convolutional_block(x, filters, strides):
  """
  Used when input and output dimensions don't match

  [(1x1conv+BN+Relu -> 3x3conv+BN+Relu -> 1x1conv+BN)  + skip(1x1conv+BN)] -> Relu
  """

  shortcut = x

  x = conv_block(x, filters, kernel_size=1, strides=strides)
  x = conv_block(x, filters, kernel_size=3, strides=1)
  x = Conv2D(filters=filters*4, kernel_size=1)(x)
  x = BatchNormalization()(x)

  shortcut = Conv2D(filters=filters*4, kernel_size=1, strides=strides)(shortcut)
  shortcut = BatchNormalization()(shortcut)

  x = Add()([x, shortcut])
  x = Activation('relu')(x)
  return x

# %% [markdown]
# #### Build Model

# %%
def Resnet50V1(input_shape=(224,224,3),num_classes=1000):
  """
  Resnet50-v1 model using tensorflow

  convolutional block -> when input and output dimension doesn't match
  identity block -> when input and output dimension matches

  Resnet50  -> blocks (3,4,6,3)
  """
  inputs = Input(shape=input_shape)

  # initial conv+maxpool layer
  x = Conv2D(filters=64, kernel_size=(7,7),strides=(2,2), padding='same')(inputs)
  x = BatchNormalization()(x)
  x = Activation(activation='relu')(x)
  x = MaxPooling2D(pool_size=(3,3),strides=(2,2), padding='same')(x)

  # block1
  x = convolutional_block(x, filters=64, strides=(1,1))
  x = identity_block(x, filters=64)
  x = identity_block(x, filters=64)

  # block2
  x = convolutional_block(x, filters=128, strides=(2,2))
  x = identity_block(x, filters=128)
  x = identity_block(x, filters=128)
  x = identity_block(x, filters=128)

  # block 3
  x = convolutional_block(x, filters=256, strides=(2,2))
  x = identity_block(x, filters=256)
  x = identity_block(x, filters=256)
  x = identity_block(x, filters=256)
  x = identity_block(x, filters=256)
  x = identity_block(x, filters=256)

  # block 4
  x = convolutional_block(x, filters=512, strides=(2,2))
  x = identity_block(x, filters=512)
  x = identity_block(x, filters=512)

  # global average pooling
  x = GlobalAveragePooling2D()(x)
  outputs = Dense(units=num_classes, activation='softmax')(x)

  # Model
  model = Model(inputs=inputs, outputs=outputs)
  return model

# %% [markdown]
# #### Model summary

# %%
model = Resnet50V1()
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_205 (Conv2D)         (None, 112, 112, 64)         9472      ['input_9[0][0]']
#
#  batch_normalization_206 (B  (None, 112, 112, 64)         256       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  activation_184 (Activation  (None, 112, 112, 64)         0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 56, 56, 64)           0         ['activation_184[0][0]']
#  g2D)
#
#  conv2d_206 (Conv2D)         (None, 56, 56, 64)           4160      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_207 (B  (None, 56, 56, 64)           256       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  activation_185 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  conv2d_207 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_185[0][0]']
#
#  batch_normalization_208 (B  (None, 56, 56, 64)           256       ['conv2d_207[0][0]']
#  atchNormalization)
#
#  activation_186 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  conv2d_208 (Conv2D)         (None, 56, 56, 256)          16640     ['activation_186[0][0]']
#
#  conv2d_209 (Conv2D)         (None, 56, 56, 256)          16640     ['max_pooling2d_7[0][0]']
#
#  batch_normalization_209 (B  (None, 56, 56, 256)          1024      ['conv2d_208[0][0]']
#  atchNormalization)
#
#  batch_normalization_210 (B  (None, 56, 56, 256)          1024      ['conv2d_209[0][0]']
#  atchNormalization)
#
#  add_60 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_209[0][0
#                                                                     ]',
#                                                                      'batch_normalization_210[0][0
#                                                                     ]']
#
#  activation_187 (Activation  (None, 56, 56, 256)          0         ['add_60[0][0]']
#  )
#
#  conv2d_210 (Conv2D)         (None, 56, 56, 64)           16448     ['activation_187[0][0]']
#
#  batch_normalization_211 (B  (None, 56, 56, 64)           256       ['conv2d_210[0][0]']
#  atchNormalization)
#
#  activation_188 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_211[0][0
#  )                                                                  ]']
#
#  conv2d_211 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_188[0][0]']
#
#  batch_normalization_212 (B  (None, 56, 56, 64)           256       ['conv2d_211[0][0]']
#  atchNormalization)
#
#  activation_189 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_212[0][0
#  )                                                                  ]']
#
#  conv2d_212 (Conv2D)         (None, 56, 56, 256)          16640     ['activation_189[0][0]']
#
#  batch_normalization_213 (B  (None, 56, 56, 256)          1024      ['conv2d_212[0][0]']
#  atchNormalization)
#
#  add_61 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_213[0][0
#                                                                     ]',
#                                                                      'activation_187[0][0]']
#
#  activation_190 (Activation  (None, 56, 56, 256)          0         ['add_61[0][0]']
#  )
#
#  conv2d_213 (Conv2D)         (None, 56, 56, 64)           16448     ['activation_190[0][0]']
#
#  batch_normalization_214 (B  (None, 56, 56, 64)           256       ['conv2d_213[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_214[0][0
#  )                                                                  ]']
#
#  conv2d_214 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_191[0][0]']
#
#  batch_normalization_215 (B  (None, 56, 56, 64)           256       ['conv2d_214[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_215[0][0
#  )                                                                  ]']
#
#  conv2d_215 (Conv2D)         (None, 56, 56, 256)          16640     ['activation_192[0][0]']
#
#  batch_normalization_216 (B  (None, 56, 56, 256)          1024      ['conv2d_215[0][0]']
#  atchNormalization)
#
#  add_62 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_216[0][0
#                                                                     ]',
#                                                                      'activation_190[0][0]']
#
#  activation_193 (Activation  (None, 56, 56, 256)          0         ['add_62[0][0]']
#  )
#
#  conv2d_216 (Conv2D)         (None, 28, 28, 128)          32896     ['activation_193[0][0]']
#
#  batch_normalization_217 (B  (None, 28, 28, 128)          512       ['conv2d_216[0][0]']
#  atchNormalization)
#
#  activation_194 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_217[0][0
#  )                                                                  ]']
#
#  conv2d_217 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_194[0][0]']
#
#  batch_normalization_218 (B  (None, 28, 28, 128)          512       ['conv2d_217[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_218[0][0
#  )                                                                  ]']
#
#  conv2d_218 (Conv2D)         (None, 28, 28, 512)          66048     ['activation_195[0][0]']
#
#  conv2d_219 (Conv2D)         (None, 28, 28, 512)          131584    ['activation_193[0][0]']
#
#  batch_normalization_219 (B  (None, 28, 28, 512)          2048      ['conv2d_218[0][0]']
#  atchNormalization)
#
#  batch_normalization_220 (B  (None, 28, 28, 512)          2048      ['conv2d_219[0][0]']
#  atchNormalization)
#
#  add_63 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_219[0][0
#                                                                     ]',
#                                                                      'batch_normalization_220[0][0
#                                                                     ]']
#
#  activation_196 (Activation  (None, 28, 28, 512)          0         ['add_63[0][0]']
#  )
#
#  conv2d_220 (Conv2D)         (None, 28, 28, 128)          65664     ['activation_196[0][0]']
#
#  batch_normalization_221 (B  (None, 28, 28, 128)          512       ['conv2d_220[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_221[0][0
#  )                                                                  ]']
#
#  conv2d_221 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_197[0][0]']
#
#  batch_normalization_222 (B  (None, 28, 28, 128)          512       ['conv2d_221[0][0]']
#  atchNormalization)
#
#  activation_198 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_222[0][0
#  )                                                                  ]']
#
#  conv2d_222 (Conv2D)         (None, 28, 28, 512)          66048     ['activation_198[0][0]']
#
#  batch_normalization_223 (B  (None, 28, 28, 512)          2048      ['conv2d_222[0][0]']
#  atchNormalization)
#
#  add_64 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_223[0][0
#                                                                     ]',
#                                                                      'activation_196[0][0]']
#
#  activation_199 (Activation  (None, 28, 28, 512)          0         ['add_64[0][0]']
#  )
#
#  conv2d_223 (Conv2D)         (None, 28, 28, 128)          65664     ['activation_199[0][0]']
#
#  batch_normalization_224 (B  (None, 28, 28, 128)          512       ['conv2d_223[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_224[0][0
#  )                                                                  ]']
#
#  conv2d_224 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_200[0][0]']
#
#  batch_normalization_225 (B  (None, 28, 28, 128)          512       ['conv2d_224[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_225[0][0
#  )                                                                  ]']
#
#  conv2d_225 (Conv2D)         (None, 28, 28, 512)          66048     ['activation_201[0][0]']
#
#  batch_normalization_226 (B  (None, 28, 28, 512)          2048      ['conv2d_225[0][0]']
#  atchNormalization)
#
#  add_65 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_226[0][0
#                                                                     ]',
#                                                                      'activation_199[0][0]']
#
#  activation_202 (Activation  (None, 28, 28, 512)          0         ['add_65[0][0]']
#  )
#
#  conv2d_226 (Conv2D)         (None, 28, 28, 128)          65664     ['activation_202[0][0]']
#
#  batch_normalization_227 (B  (None, 28, 28, 128)          512       ['conv2d_226[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  conv2d_227 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_203[0][0]']
#
#  batch_normalization_228 (B  (None, 28, 28, 128)          512       ['conv2d_227[0][0]']
#  atchNormalization)
#
#  activation_204 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_228[0][0
#  )                                                                  ]']
#
#  conv2d_228 (Conv2D)         (None, 28, 28, 512)          66048     ['activation_204[0][0]']
#
#  batch_normalization_229 (B  (None, 28, 28, 512)          2048      ['conv2d_228[0][0]']
#  atchNormalization)
#
#  add_66 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_229[0][0
#                                                                     ]',
#                                                                      'activation_202[0][0]']
#
#  activation_205 (Activation  (None, 28, 28, 512)          0         ['add_66[0][0]']
#  )
#
#  conv2d_229 (Conv2D)         (None, 14, 14, 256)          131328    ['activation_205[0][0]']
#
#  batch_normalization_230 (B  (None, 14, 14, 256)          1024      ['conv2d_229[0][0]']
#  atchNormalization)
#
#  activation_206 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_230[0][0
#  )                                                                  ]']
#
#  conv2d_230 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_206[0][0]']
#
#  batch_normalization_231 (B  (None, 14, 14, 256)          1024      ['conv2d_230[0][0]']
#  atchNormalization)
#
#  activation_207 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  conv2d_231 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_207[0][0]']
#
#  conv2d_232 (Conv2D)         (None, 14, 14, 1024)         525312    ['activation_205[0][0]']
#
#  batch_normalization_232 (B  (None, 14, 14, 1024)         4096      ['conv2d_231[0][0]']
#  atchNormalization)
#
#  batch_normalization_233 (B  (None, 14, 14, 1024)         4096      ['conv2d_232[0][0]']
#  atchNormalization)
#
#  add_67 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_232[0][0
#                                                                     ]',
#                                                                      'batch_normalization_233[0][0
#                                                                     ]']
#
#  activation_208 (Activation  (None, 14, 14, 1024)         0         ['add_67[0][0]']
#  )
#
#  conv2d_233 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_208[0][0]']
#
#  batch_normalization_234 (B  (None, 14, 14, 256)          1024      ['conv2d_233[0][0]']
#  atchNormalization)
#
#  activation_209 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  conv2d_234 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_209[0][0]']
#
#  batch_normalization_235 (B  (None, 14, 14, 256)          1024      ['conv2d_234[0][0]']
#  atchNormalization)
#
#  activation_210 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  conv2d_235 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_210[0][0]']
#
#  batch_normalization_236 (B  (None, 14, 14, 1024)         4096      ['conv2d_235[0][0]']
#  atchNormalization)
#
#  add_68 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_236[0][0
#                                                                     ]',
#                                                                      'activation_208[0][0]']
#
#  activation_211 (Activation  (None, 14, 14, 1024)         0         ['add_68[0][0]']
#  )
#
#  conv2d_236 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_211[0][0]']
#
#  batch_normalization_237 (B  (None, 14, 14, 256)          1024      ['conv2d_236[0][0]']
#  atchNormalization)
#
#  activation_212 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  conv2d_237 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_212[0][0]']
#
#  batch_normalization_238 (B  (None, 14, 14, 256)          1024      ['conv2d_237[0][0]']
#  atchNormalization)
#
#  activation_213 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_238[0][0
#  )                                                                  ]']
#
#  conv2d_238 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_213[0][0]']
#
#  batch_normalization_239 (B  (None, 14, 14, 1024)         4096      ['conv2d_238[0][0]']
#  atchNormalization)
#
#  add_69 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_239[0][0
#                                                                     ]',
#                                                                      'activation_211[0][0]']
#
#  activation_214 (Activation  (None, 14, 14, 1024)         0         ['add_69[0][0]']
#  )
#
#  conv2d_239 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_214[0][0]']
#
#  batch_normalization_240 (B  (None, 14, 14, 256)          1024      ['conv2d_239[0][0]']
#  atchNormalization)
#
#  activation_215 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_240[0][0
#  )                                                                  ]']
#
#  conv2d_240 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_215[0][0]']
#
#  batch_normalization_241 (B  (None, 14, 14, 256)          1024      ['conv2d_240[0][0]']
#  atchNormalization)
#
#  activation_216 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_241[0][0
#  )                                                                  ]']
#
#  conv2d_241 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_216[0][0]']
#
#  batch_normalization_242 (B  (None, 14, 14, 1024)         4096      ['conv2d_241[0][0]']
#  atchNormalization)
#
#  add_70 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_242[0][0
#                                                                     ]',
#                                                                      'activation_214[0][0]']
#
#  activation_217 (Activation  (None, 14, 14, 1024)         0         ['add_70[0][0]']
#  )
#
#  conv2d_242 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_217[0][0]']
#
#  batch_normalization_243 (B  (None, 14, 14, 256)          1024      ['conv2d_242[0][0]']
#  atchNormalization)
#
#  activation_218 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_243[0][0
#  )                                                                  ]']
#
#  conv2d_243 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_218[0][0]']
#
#  batch_normalization_244 (B  (None, 14, 14, 256)          1024      ['conv2d_243[0][0]']
#  atchNormalization)
#
#  activation_219 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_244[0][0
#  )                                                                  ]']
#
#  conv2d_244 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_219[0][0]']
#
#  batch_normalization_245 (B  (None, 14, 14, 1024)         4096      ['conv2d_244[0][0]']
#  atchNormalization)
#
#  add_71 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_245[0][0
#                                                                     ]',
#                                                                      'activation_217[0][0]']
#
#  activation_220 (Activation  (None, 14, 14, 1024)         0         ['add_71[0][0]']
#  )
#
#  conv2d_245 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_220[0][0]']
#
#  batch_normalization_246 (B  (None, 14, 14, 256)          1024      ['conv2d_245[0][0]']
#  atchNormalization)
#
#  activation_221 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_246[0][0
#  )                                                                  ]']
#
#  conv2d_246 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_221[0][0]']
#
#  batch_normalization_247 (B  (None, 14, 14, 256)          1024      ['conv2d_246[0][0]']
#  atchNormalization)
#
#  activation_222 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_247[0][0
#  )                                                                  ]']
#
#  conv2d_247 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_222[0][0]']
#
#  batch_normalization_248 (B  (None, 14, 14, 1024)         4096      ['conv2d_247[0][0]']
#  atchNormalization)
#
#  add_72 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_248[0][0
#                                                                     ]',
#                                                                      'activation_220[0][0]']
#
#  activation_223 (Activation  (None, 14, 14, 1024)         0         ['add_72[0][0]']
#  )
#
#  conv2d_248 (Conv2D)         (None, 7, 7, 512)            524800    ['activation_223[0][0]']
#
#  batch_normalization_249 (B  (None, 7, 7, 512)            2048      ['conv2d_248[0][0]']
#  atchNormalization)
#
#  activation_224 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_249[0][0
#  )                                                                  ]']
#
#  conv2d_249 (Conv2D)         (None, 7, 7, 512)            2359808   ['activation_224[0][0]']
#
#  batch_normalization_250 (B  (None, 7, 7, 512)            2048      ['conv2d_249[0][0]']
#  atchNormalization)
#
#  activation_225 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_250[0][0
#  )                                                                  ]']
#
#  conv2d_250 (Conv2D)         (None, 7, 7, 2048)           1050624   ['activation_225[0][0]']
#
#  conv2d_251 (Conv2D)         (None, 7, 7, 2048)           2099200   ['activation_223[0][0]']
#
#  batch_normalization_251 (B  (None, 7, 7, 2048)           8192      ['conv2d_250[0][0]']
#  atchNormalization)
#
#  batch_normalization_252 (B  (None, 7, 7, 2048)           8192      ['conv2d_251[0][0]']
#  atchNormalization)
#
#  add_73 (Add)                (None, 7, 7, 2048)           0         ['batch_normalization_251[0][0
#                                                                     ]',
#                                                                      'batch_normalization_252[0][0
#                                                                     ]']
#
#  activation_226 (Activation  (None, 7, 7, 2048)           0         ['add_73[0][0]']
#  )
#
#  conv2d_252 (Conv2D)         (None, 7, 7, 512)            1049088   ['activation_226[0][0]']
#
#  batch_normalization_253 (B  (None, 7, 7, 512)            2048      ['conv2d_252[0][0]']
#  atchNormalization)
#
#  activation_227 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_253[0][0
#  )                                                                  ]']
#
#  conv2d_253 (Conv2D)         (None, 7, 7, 512)            2359808   ['activation_227[0][0]']
#
#  batch_normalization_254 (B  (None, 7, 7, 512)            2048      ['conv2d_253[0][0]']
#  atchNormalization)
#
#  activation_228 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_254[0][0
#  )                                                                  ]']
#
#  conv2d_254 (Conv2D)         (None, 7, 7, 2048)           1050624   ['activation_228[0][0]']
#
#  batch_normalization_255 (B  (None, 7, 7, 2048)           8192      ['conv2d_254[0][0]']
#  atchNormalization)
#
#  add_74 (Add)                (None, 7, 7, 2048)           0         ['batch_normalization_255[0][0
#                                                                     ]',
#                                                                      'activation_226[0][0]']
#
#  activation_229 (Activation  (None, 7, 7, 2048)           0         ['add_74[0][0]']
#  )
#
#  conv2d_255 (Conv2D)         (None, 7, 7, 512)            1049088   ['activation_229[0][0]']
#
#  batch_normalization_256 (B  (None, 7, 7, 512)            2048      ['conv2d_255[0][0]']
#  atchNormalization)
#
#  activation_230 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_256[0][0
#  )                                                                  ]']
#
#  conv2d_256 (Conv2D)         (None, 7, 7, 512)            2359808   ['activation_230[0][0]']
#
#  batch_normalization_257 (B  (None, 7, 7, 512)            2048      ['conv2d_256[0][0]']
#  atchNormalization)
#
#  activation_231 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_257[0][0
#  )                                                                  ]']
#
#  conv2d_257 (Conv2D)         (None, 7, 7, 2048)           1050624   ['activation_231[0][0]']
#
#  batch_normalization_258 (B  (None, 7, 7, 2048)           8192      ['conv2d_257[0][0]']
#  atchNormalization)
#
#  add_75 (Add)                (None, 7, 7, 2048)           0         ['batch_normalization_258[0][0
#                                                                     ]',
#                                                                      'activation_229[0][0]']
#
#  activation_232 (Activation  (None, 7, 7, 2048)           0         ['add_75[0][0]']
#  )
#
#  global_average_pooling2d_3  (None, 2048)                 0         ['activation_232[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 1000)                 2049000   ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 25636712 (97.80 MB)
# Trainable params: 25583592 (97.59 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________
