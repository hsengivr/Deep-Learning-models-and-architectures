# %% [markdown]
# ### Import libraries

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv2D, BatchNormalization, ReLU, MaxPool2D, Flatten, Activation, GlobalAveragePooling2D, AveragePooling2D, Dropout, Concatenate
from tensorflow.keras.models import Model

# %% [markdown]
# ### Conv + BN + Relu

# %%
def conv_bn_relu(prev_layer , filters , kernel_size , strides =(1,1) , padding = 'same'):
  x = Conv2D(filters=filters, kernel_size = kernel_size, strides=strides , padding=padding)(prev_layer)
  x = BatchNormalization(axis=3)(x)
  x = Activation(activation='relu')(x)
  return x

# %% [markdown]
# ### Stem block

# %%
def StemBlock(prev_layer):
  """
  Operations done before Inception and resuction blocks
  """
  x = conv_bn_relu(prev_layer, filters = 32, kernel_size=(3,3) , strides=(2,2))
  x = conv_bn_relu(x, filters = 32, kernel_size=(3,3))
  x = conv_bn_relu(x, filters = 64, kernel_size=(3,3))
  x = MaxPool2D(pool_size=(3,3) , strides=(2,2)) (x)
  x = conv_bn_relu(x, filters = 80, kernel_size=(1,1))
  x = conv_bn_relu(x, filters = 192, kernel_size=(3,3))
  x = MaxPool2D(pool_size=(3,3) , strides=(2,2)) (x)

  return x

# %% [markdown]
# ### Inception blocks

# %%
def InceptionBlock_A(prev_layer  , filters):

  branch1 = conv_bn_relu(prev_layer, filters = 64, kernel_size = (1,1))
  branch1 = conv_bn_relu(branch1, filters=96, kernel_size=(3,3))
  branch1 = conv_bn_relu(branch1, filters=96, kernel_size=(3,3))

  branch2 = conv_bn_relu(prev_layer, filters=48, kernel_size=(1,1))
  branch2 = conv_bn_relu(branch2, filters=64, kernel_size=(3,3)) # may be 3*3

  branch3 = AveragePooling2D(pool_size=(3,3) , strides=(1,1) , padding='same') (prev_layer)
  branch3 = conv_bn_relu(branch3, filters = filters, kernel_size = (1,1))

  branch4 = conv_bn_relu(prev_layer, filters=64, kernel_size=(1,1))

  output = Concatenate(axis=3)([branch1 , branch2 , branch3 , branch4])

  return output

# %%
def InceptionBlock_B(prev_layer , filters):

  branch1 = conv_bn_relu(prev_layer, filters = filters, kernel_size = (1,1))
  branch1 = conv_bn_relu(branch1, filters = filters, kernel_size = (7,1))
  branch1 = conv_bn_relu(branch1, filters = filters, kernel_size = (1,7))
  branch1 = conv_bn_relu(branch1, filters = filters, kernel_size = (7,1))
  branch1 = conv_bn_relu(branch1, filters = 192, kernel_size = (1,7))

  branch2 = conv_bn_relu(prev_layer, filters = filters, kernel_size = (1,1))
  branch2 = conv_bn_relu(branch2, filters = filters, kernel_size = (1,7))
  branch2 = conv_bn_relu(branch2, filters = 192, kernel_size = (7,1))

  branch3 = AveragePooling2D(pool_size=(3,3) , strides=(1,1) , padding ='same') (prev_layer)
  branch3 = conv_bn_relu(branch3, filters = 192, kernel_size = (1,1))

  branch4 = conv_bn_relu(prev_layer, filters = 192, kernel_size = (1,1))

  output = Concatenate(axis=3)([branch1 , branch2 , branch3 , branch4])

  return output

# %%
def InceptionBlock_C(prev_layer):

  branch1 = conv_bn_relu(prev_layer, filters = 448, kernel_size = (1,1))
  branch1 = conv_bn_relu(branch1, filters = 384, kernel_size = (3,3))
  branch1_1 = conv_bn_relu(branch1, filters = 384, kernel_size = (1,3))
  branch1_2 =conv_bn_relu(branch1, filters = 384, kernel_size = (3,1))
  branch1 = Concatenate(axis=3)([branch1_1 , branch1_2])

  branch2 = conv_bn_relu(prev_layer, filters = 384, kernel_size = (1,1))
  branch2_1 = conv_bn_relu(branch2, filters = 384, kernel_size = (1,3))
  branch2_2 = conv_bn_relu(branch2, filters = 384, kernel_size = (3,1))
  branch2 = Concatenate(axis = 3)([branch2_1 , branch2_2])

  branch3 = AveragePooling2D(pool_size=(3,3) , strides=(1,1) , padding='same')(prev_layer)
  branch3 = conv_bn_relu(branch3, filters = 192, kernel_size = (1,1))

  branch4 = conv_bn_relu(prev_layer, filters = 320, kernel_size = (1,1))

  output = Concatenate(axis = 3)([branch1 , branch2 , branch3 , branch4])

  return output

# %% [markdown]
# ### Reduction blocks
#
# ```
# # This is formatted as code
# ```

# %%
def ReductionBlock_A(prev_layer):

  branch1 = conv_bn_relu(prev_layer, filters = 64, kernel_size = (1,1))
  branch1 = conv_bn_relu(branch1, filters = 96, kernel_size = (3,3))
  branch1 = conv_bn_relu(branch1, filters = 96, kernel_size = (3,3) , strides=(2,2) ) #, padding='valid'

  branch2 = conv_bn_relu(prev_layer, filters = 384, kernel_size=(3,3) , strides=(2,2) )

  branch3 = MaxPool2D(pool_size=(3,3) , strides=(2,2) , padding='same')(prev_layer)

  output = Concatenate(axis = 3)([branch1 , branch2 , branch3])

  return output

# %%
def ReductionBlock_B(prev_layer):

  branch1 = conv_bn_relu(prev_layer, filters = 192, kernel_size = (1,1))
  branch1 = conv_bn_relu(branch1, filters = 192, kernel_size = (1,7))
  branch1 = conv_bn_relu(branch1, filters = 192, kernel_size = (7,1))
  branch1 = conv_bn_relu(branch1, filters = 192, kernel_size = (3,3) , strides=(2,2) , padding = 'valid')

  branch2 = conv_bn_relu(prev_layer, filters = 192, kernel_size = (1,1) )
  branch2 = conv_bn_relu(branch2, filters = 320, kernel_size = (3,3) , strides=(2,2) , padding='valid' )

  branch3 = MaxPool2D(pool_size=(3,3) , strides=(2,2) )(prev_layer)

  output = Concatenate(axis = 3)([branch1 , branch2 , branch3])

  return output

# %%
def auxiliary_classifier(prev_Layer):
  x = AveragePooling2D(pool_size=(5,5) , strides=(3,3)) (prev_Layer)
  x = conv_bn_relu(x, filters = 128, kernel_size = (1,1))
  x = Flatten()(x)
  x = Dense(units = 768, activation='relu') (x)
  x = Dropout(rate = 0.2) (x)
  x = Dense(units = 1000, activation='softmax') (x)
  return x

# %% [markdown]
# ### InceptionV3 Model

# %%
def InceptionV3():
  """
  Inceptionv3 Model
  - Factorized 7x7 convolutions.
  - BatchNorm in the Auxillary Classifiers.
  - Label Smoothing

  Model input size : (299, 299, 3)
  """

  input_layer = Input(shape=(299 , 299 , 3))

  x = StemBlock(input_layer)

  x = InceptionBlock_A(prev_layer = x ,filters = 32)
  x = InceptionBlock_A(prev_layer = x ,filters = 64)
  x = InceptionBlock_A(prev_layer = x ,filters = 64)

  x = ReductionBlock_A(prev_layer = x )

  x = InceptionBlock_B(prev_layer = x  , filters = 128)
  x = InceptionBlock_B(prev_layer = x , filters = 160)
  x = InceptionBlock_B(prev_layer = x , filters = 160)
  x = InceptionBlock_B(prev_layer = x , filters = 192)

  Aux = auxiliary_classifier(prev_Layer = x)

  x = ReductionBlock_B(prev_layer = x)

  x = InceptionBlock_C(prev_layer = x)
  x = InceptionBlock_C(prev_layer = x)

  x = GlobalAveragePooling2D()(x)
  x = Dense(units=2048, activation='relu') (x)
  x = Dropout(rate = 0.2) (x)
  x = Dense(units=1000, activation='softmax') (x)

  # model = Model(inputs = input_layer , outputs = [x , Aux] , name = 'Inception-V3')
  model = Model(inputs = input_layer , outputs = x , name = 'Inception-V3')


  return model

# %%
model = InceptionV3()
model.summary()
# Out:
# Model: "Inception-V3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_81 (Conv2D)          (None, 150, 150, 32)         896       ['input_2[0][0]']
#
#  batch_normalization_81 (Ba  (None, 150, 150, 32)         128       ['conv2d_81[0][0]']
#  tchNormalization)
#
#  activation_81 (Activation)  (None, 150, 150, 32)         0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_82 (Conv2D)          (None, 150, 150, 32)         9248      ['activation_81[0][0]']
#
#  batch_normalization_82 (Ba  (None, 150, 150, 32)         128       ['conv2d_82[0][0]']
#  tchNormalization)
#
#  activation_82 (Activation)  (None, 150, 150, 32)         0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  conv2d_83 (Conv2D)          (None, 150, 150, 64)         18496     ['activation_82[0][0]']
#
#  batch_normalization_83 (Ba  (None, 150, 150, 64)         256       ['conv2d_83[0][0]']
#  tchNormalization)
#
#  activation_83 (Activation)  (None, 150, 150, 64)         0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 74, 74, 64)           0         ['activation_83[0][0]']
#  g2D)
#
#  conv2d_84 (Conv2D)          (None, 74, 74, 80)           5200      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_84 (Ba  (None, 74, 74, 80)           320       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_84 (Activation)  (None, 74, 74, 80)           0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  conv2d_85 (Conv2D)          (None, 74, 74, 192)          138432    ['activation_84[0][0]']
#
#  batch_normalization_85 (Ba  (None, 74, 74, 192)          768       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 74, 74, 192)          0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 36, 36, 192)          0         ['activation_85[0][0]']
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 36, 36, 64)           12352     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_86 (Ba  (None, 36, 36, 64)           256       ['conv2d_86[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 36, 36, 64)           0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 36, 36, 96)           55392     ['activation_86[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 36, 36, 48)           9264      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_87 (Ba  (None, 36, 36, 96)           384       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_89 (Ba  (None, 36, 36, 48)           192       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 36, 36, 96)           0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_89 (Activation)  (None, 36, 36, 48)           0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  average_pooling2d_8 (Avera  (None, 36, 36, 192)          0         ['max_pooling2d_5[0][0]']
#  gePooling2D)
#
#  conv2d_88 (Conv2D)          (None, 36, 36, 96)           83040     ['activation_87[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 36, 36, 64)           27712     ['activation_89[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 36, 36, 32)           6176      ['average_pooling2d_8[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 36, 36, 64)           12352     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_88 (Ba  (None, 36, 36, 96)           384       ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 36, 36, 64)           256       ['conv2d_90[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 36, 36, 32)           128       ['conv2d_91[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 36, 36, 64)           256       ['conv2d_92[0][0]']
#  tchNormalization)
#
#  activation_88 (Activation)  (None, 36, 36, 96)           0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 36, 36, 64)           0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 36, 36, 32)           0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  activation_92 (Activation)  (None, 36, 36, 64)           0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  concatenate_9 (Concatenate  (None, 36, 36, 256)          0         ['activation_88[0][0]',
#  )                                                                   'activation_90[0][0]',
#                                                                      'activation_91[0][0]',
#                                                                      'activation_92[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 36, 36, 64)           16448     ['concatenate_9[0][0]']
#
#  batch_normalization_93 (Ba  (None, 36, 36, 64)           256       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_93 (Activation)  (None, 36, 36, 64)           0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  conv2d_94 (Conv2D)          (None, 36, 36, 96)           55392     ['activation_93[0][0]']
#
#  conv2d_96 (Conv2D)          (None, 36, 36, 48)           12336     ['concatenate_9[0][0]']
#
#  batch_normalization_94 (Ba  (None, 36, 36, 96)           384       ['conv2d_94[0][0]']
#  tchNormalization)
#
#  batch_normalization_96 (Ba  (None, 36, 36, 48)           192       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 36, 36, 96)           0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  activation_96 (Activation)  (None, 36, 36, 48)           0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  average_pooling2d_9 (Avera  (None, 36, 36, 256)          0         ['concatenate_9[0][0]']
#  gePooling2D)
#
#  conv2d_95 (Conv2D)          (None, 36, 36, 96)           83040     ['activation_94[0][0]']
#
#  conv2d_97 (Conv2D)          (None, 36, 36, 64)           27712     ['activation_96[0][0]']
#
#  conv2d_98 (Conv2D)          (None, 36, 36, 64)           16448     ['average_pooling2d_9[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 36, 36, 64)           16448     ['concatenate_9[0][0]']
#
#  batch_normalization_95 (Ba  (None, 36, 36, 96)           384       ['conv2d_95[0][0]']
#  tchNormalization)
#
#  batch_normalization_97 (Ba  (None, 36, 36, 64)           256       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  batch_normalization_98 (Ba  (None, 36, 36, 64)           256       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  batch_normalization_99 (Ba  (None, 36, 36, 64)           256       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 36, 36, 96)           0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  activation_97 (Activation)  (None, 36, 36, 64)           0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  activation_98 (Activation)  (None, 36, 36, 64)           0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  activation_99 (Activation)  (None, 36, 36, 64)           0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  concatenate_10 (Concatenat  (None, 36, 36, 288)          0         ['activation_95[0][0]',
#  e)                                                                  'activation_97[0][0]',
#                                                                      'activation_98[0][0]',
#                                                                      'activation_99[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 36, 36, 64)           18496     ['concatenate_10[0][0]']
#
#  batch_normalization_100 (B  (None, 36, 36, 64)           256       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 36, 36, 64)           0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  conv2d_101 (Conv2D)         (None, 36, 36, 96)           55392     ['activation_100[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 36, 36, 48)           13872     ['concatenate_10[0][0]']
#
#  batch_normalization_101 (B  (None, 36, 36, 96)           384       ['conv2d_101[0][0]']
#  atchNormalization)
#
#  batch_normalization_103 (B  (None, 36, 36, 48)           192       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  activation_101 (Activation  (None, 36, 36, 96)           0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  activation_103 (Activation  (None, 36, 36, 48)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  average_pooling2d_10 (Aver  (None, 36, 36, 288)          0         ['concatenate_10[0][0]']
#  agePooling2D)
#
#  conv2d_102 (Conv2D)         (None, 36, 36, 96)           83040     ['activation_101[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 36, 36, 64)           27712     ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 36, 36, 64)           18496     ['average_pooling2d_10[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 36, 36, 64)           18496     ['concatenate_10[0][0]']
#
#  batch_normalization_102 (B  (None, 36, 36, 96)           384       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  batch_normalization_104 (B  (None, 36, 36, 64)           256       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 36, 36, 64)           256       ['conv2d_105[0][0]']
#  atchNormalization)
#
#  batch_normalization_106 (B  (None, 36, 36, 64)           256       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_102 (Activation  (None, 36, 36, 96)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  activation_104 (Activation  (None, 36, 36, 64)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  activation_105 (Activation  (None, 36, 36, 64)           0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  activation_106 (Activation  (None, 36, 36, 64)           0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  concatenate_11 (Concatenat  (None, 36, 36, 288)          0         ['activation_102[0][0]',
#  e)                                                                  'activation_104[0][0]',
#                                                                      'activation_105[0][0]',
#                                                                      'activation_106[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 36, 36, 64)           18496     ['concatenate_11[0][0]']
#
#  batch_normalization_107 (B  (None, 36, 36, 64)           256       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 36, 36, 64)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  conv2d_108 (Conv2D)         (None, 36, 36, 96)           55392     ['activation_107[0][0]']
#
#  batch_normalization_108 (B  (None, 36, 36, 96)           384       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, 36, 36, 96)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  conv2d_109 (Conv2D)         (None, 18, 18, 96)           83040     ['activation_108[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 18, 18, 384)          995712    ['concatenate_11[0][0]']
#
#  batch_normalization_109 (B  (None, 18, 18, 96)           384       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 18, 18, 384)          1536      ['conv2d_110[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 18, 18, 96)           0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  activation_110 (Activation  (None, 18, 18, 384)          0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 18, 18, 288)          0         ['concatenate_11[0][0]']
#  g2D)
#
#  concatenate_12 (Concatenat  (None, 18, 18, 768)          0         ['activation_109[0][0]',
#  e)                                                                  'activation_110[0][0]',
#                                                                      'max_pooling2d_6[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 18, 18, 128)          98432     ['concatenate_12[0][0]']
#
#  batch_normalization_111 (B  (None, 18, 18, 128)          512       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  activation_111 (Activation  (None, 18, 18, 128)          0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  conv2d_112 (Conv2D)         (None, 18, 18, 128)          114816    ['activation_111[0][0]']
#
#  batch_normalization_112 (B  (None, 18, 18, 128)          512       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_112 (Activation  (None, 18, 18, 128)          0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  conv2d_113 (Conv2D)         (None, 18, 18, 128)          114816    ['activation_112[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 18, 18, 128)          98432     ['concatenate_12[0][0]']
#
#  batch_normalization_113 (B  (None, 18, 18, 128)          512       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  batch_normalization_116 (B  (None, 18, 18, 128)          512       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  activation_113 (Activation  (None, 18, 18, 128)          0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  activation_116 (Activation  (None, 18, 18, 128)          0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  conv2d_114 (Conv2D)         (None, 18, 18, 128)          114816    ['activation_113[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 18, 18, 128)          114816    ['activation_116[0][0]']
#
#  batch_normalization_114 (B  (None, 18, 18, 128)          512       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 18, 18, 128)          512       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  activation_114 (Activation  (None, 18, 18, 128)          0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  activation_117 (Activation  (None, 18, 18, 128)          0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  average_pooling2d_11 (Aver  (None, 18, 18, 768)          0         ['concatenate_12[0][0]']
#  agePooling2D)
#
#  conv2d_115 (Conv2D)         (None, 18, 18, 192)          172224    ['activation_114[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 18, 18, 192)          172224    ['activation_117[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 18, 18, 192)          147648    ['average_pooling2d_11[0][0]']
#
#  conv2d_120 (Conv2D)         (None, 18, 18, 192)          147648    ['concatenate_12[0][0]']
#
#  batch_normalization_115 (B  (None, 18, 18, 192)          768       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 18, 18, 192)          768       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 18, 18, 192)          768       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  batch_normalization_120 (B  (None, 18, 18, 192)          768       ['conv2d_120[0][0]']
#  atchNormalization)
#
#  activation_115 (Activation  (None, 18, 18, 192)          0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  activation_118 (Activation  (None, 18, 18, 192)          0         ['batch_normalization_118[0][0
#  )                                                                  ]']
#
#  activation_119 (Activation  (None, 18, 18, 192)          0         ['batch_normalization_119[0][0
#  )                                                                  ]']
#
#  activation_120 (Activation  (None, 18, 18, 192)          0         ['batch_normalization_120[0][0
#  )                                                                  ]']
#
#  concatenate_13 (Concatenat  (None, 18, 18, 768)          0         ['activation_115[0][0]',
#  e)                                                                  'activation_118[0][0]',
#                                                                      'activation_119[0][0]',
#                                                                      'activation_120[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 18, 18, 160)          123040    ['concatenate_13[0][0]']
#
#  batch_normalization_121 (B  (None, 18, 18, 160)          640       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  activation_121 (Activation  (None, 18, 18, 160)          0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  conv2d_122 (Conv2D)         (None, 18, 18, 160)          179360    ['activation_121[0][0]']
#
#  batch_normalization_122 (B  (None, 18, 18, 160)          640       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  activation_122 (Activation  (None, 18, 18, 160)          0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  conv2d_123 (Conv2D)         (None, 18, 18, 160)          179360    ['activation_122[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 18, 18, 160)          123040    ['concatenate_13[0][0]']
#
#  batch_normalization_123 (B  (None, 18, 18, 160)          640       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  batch_normalization_126 (B  (None, 18, 18, 160)          640       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  activation_123 (Activation  (None, 18, 18, 160)          0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  activation_126 (Activation  (None, 18, 18, 160)          0         ['batch_normalization_126[0][0
#  )                                                                  ]']
#
#  conv2d_124 (Conv2D)         (None, 18, 18, 160)          179360    ['activation_123[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 18, 18, 160)          179360    ['activation_126[0][0]']
#
#  batch_normalization_124 (B  (None, 18, 18, 160)          640       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  batch_normalization_127 (B  (None, 18, 18, 160)          640       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  activation_124 (Activation  (None, 18, 18, 160)          0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  activation_127 (Activation  (None, 18, 18, 160)          0         ['batch_normalization_127[0][0
#  )                                                                  ]']
#
#  average_pooling2d_12 (Aver  (None, 18, 18, 768)          0         ['concatenate_13[0][0]']
#  agePooling2D)
#
#  conv2d_125 (Conv2D)         (None, 18, 18, 192)          215232    ['activation_124[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 18, 18, 192)          215232    ['activation_127[0][0]']
#
#  conv2d_129 (Conv2D)         (None, 18, 18, 192)          147648    ['average_pooling2d_12[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 18, 18, 192)          147648    ['concatenate_13[0][0]']
#
#  batch_normalization_125 (B  (None, 18, 18, 192)          768       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  batch_normalization_128 (B  (None, 18, 18, 192)          768       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  batch_normalization_129 (B  (None, 18, 18, 192)          768       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  batch_normalization_130 (B  (None, 18, 18, 192)          768       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  activation_125 (Activation  (None, 18, 18, 192)          0         ['batch_normalization_125[0][0
#  )                                                                  ]']
#
#  activation_128 (Activation  (None, 18, 18, 192)          0         ['batch_normalization_128[0][0
#  )                                                                  ]']
#
#  activation_129 (Activation  (None, 18, 18, 192)          0         ['batch_normalization_129[0][0
#  )                                                                  ]']
#
#  activation_130 (Activation  (None, 18, 18, 192)          0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  concatenate_14 (Concatenat  (None, 18, 18, 768)          0         ['activation_125[0][0]',
#  e)                                                                  'activation_128[0][0]',
#                                                                      'activation_129[0][0]',
#                                                                      'activation_130[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 18, 18, 160)          123040    ['concatenate_14[0][0]']
#
#  batch_normalization_131 (B  (None, 18, 18, 160)          640       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_131 (Activation  (None, 18, 18, 160)          0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  conv2d_132 (Conv2D)         (None, 18, 18, 160)          179360    ['activation_131[0][0]']
#
#  batch_normalization_132 (B  (None, 18, 18, 160)          640       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  activation_132 (Activation  (None, 18, 18, 160)          0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  conv2d_133 (Conv2D)         (None, 18, 18, 160)          179360    ['activation_132[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 18, 18, 160)          123040    ['concatenate_14[0][0]']
#
#  batch_normalization_133 (B  (None, 18, 18, 160)          640       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  batch_normalization_136 (B  (None, 18, 18, 160)          640       ['conv2d_136[0][0]']
#  atchNormalization)
#
# ...
#  conv2d_160 (Conv2D)         (None, 8, 8, 384)            442752    ['activation_159[0][0]']
#
#  conv2d_161 (Conv2D)         (None, 8, 8, 384)            442752    ['activation_159[0][0]']
#
#  conv2d_163 (Conv2D)         (None, 8, 8, 384)            442752    ['activation_162[0][0]']
#
#  conv2d_164 (Conv2D)         (None, 8, 8, 384)            442752    ['activation_162[0][0]']
#
#  average_pooling2d_16 (Aver  (None, 8, 8, 1280)           0         ['concatenate_17[0][0]']
#  agePooling2D)
#
#  batch_normalization_160 (B  (None, 8, 8, 384)            1536      ['conv2d_160[0][0]']
#  atchNormalization)
#
#  batch_normalization_161 (B  (None, 8, 8, 384)            1536      ['conv2d_161[0][0]']
#  atchNormalization)
#
#  batch_normalization_163 (B  (None, 8, 8, 384)            1536      ['conv2d_163[0][0]']
#  atchNormalization)
#
#  batch_normalization_164 (B  (None, 8, 8, 384)            1536      ['conv2d_164[0][0]']
#  atchNormalization)
#
#  conv2d_165 (Conv2D)         (None, 8, 8, 192)            245952    ['average_pooling2d_16[0][0]']
#
#  conv2d_166 (Conv2D)         (None, 8, 8, 320)            409920    ['concatenate_17[0][0]']
#
#  activation_160 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_160[0][0
#  )                                                                  ]']
#
#  activation_161 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_161[0][0
#  )                                                                  ]']
#
#  activation_163 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_163[0][0
#  )                                                                  ]']
#
#  activation_164 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_164[0][0
#  )                                                                  ]']
#
#  batch_normalization_165 (B  (None, 8, 8, 192)            768       ['conv2d_165[0][0]']
#  atchNormalization)
#
#  batch_normalization_166 (B  (None, 8, 8, 320)            1280      ['conv2d_166[0][0]']
#  atchNormalization)
#
#  concatenate_18 (Concatenat  (None, 8, 8, 768)            0         ['activation_160[0][0]',
#  e)                                                                  'activation_161[0][0]']
#
#  concatenate_19 (Concatenat  (None, 8, 8, 768)            0         ['activation_163[0][0]',
#  e)                                                                  'activation_164[0][0]']
#
#  activation_165 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_165[0][0
#  )                                                                  ]']
#
#  activation_166 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_166[0][0
#  )                                                                  ]']
#
#  concatenate_20 (Concatenat  (None, 8, 8, 2048)           0         ['concatenate_18[0][0]',
#  e)                                                                  'concatenate_19[0][0]',
#                                                                      'activation_165[0][0]',
#                                                                      'activation_166[0][0]']
#
#  conv2d_167 (Conv2D)         (None, 8, 8, 448)            917952    ['concatenate_20[0][0]']
#
#  batch_normalization_167 (B  (None, 8, 8, 448)            1792      ['conv2d_167[0][0]']
#  atchNormalization)
#
#  activation_167 (Activation  (None, 8, 8, 448)            0         ['batch_normalization_167[0][0
#  )                                                                  ]']
#
#  conv2d_168 (Conv2D)         (None, 8, 8, 384)            1548672   ['activation_167[0][0]']
#
#  conv2d_171 (Conv2D)         (None, 8, 8, 384)            786816    ['concatenate_20[0][0]']
#
#  batch_normalization_168 (B  (None, 8, 8, 384)            1536      ['conv2d_168[0][0]']
#  atchNormalization)
#
#  batch_normalization_171 (B  (None, 8, 8, 384)            1536      ['conv2d_171[0][0]']
#  atchNormalization)
#
#  activation_168 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_168[0][0
#  )                                                                  ]']
#
#  activation_171 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_171[0][0
#  )                                                                  ]']
#
#  conv2d_169 (Conv2D)         (None, 8, 8, 384)            442752    ['activation_168[0][0]']
#
#  conv2d_170 (Conv2D)         (None, 8, 8, 384)            442752    ['activation_168[0][0]']
#
#  conv2d_172 (Conv2D)         (None, 8, 8, 384)            442752    ['activation_171[0][0]']
#
#  conv2d_173 (Conv2D)         (None, 8, 8, 384)            442752    ['activation_171[0][0]']
#
#  average_pooling2d_17 (Aver  (None, 8, 8, 2048)           0         ['concatenate_20[0][0]']
#  agePooling2D)
#
#  batch_normalization_169 (B  (None, 8, 8, 384)            1536      ['conv2d_169[0][0]']
#  atchNormalization)
#
#  batch_normalization_170 (B  (None, 8, 8, 384)            1536      ['conv2d_170[0][0]']
#  atchNormalization)
#
#  batch_normalization_172 (B  (None, 8, 8, 384)            1536      ['conv2d_172[0][0]']
#  atchNormalization)
#
#  batch_normalization_173 (B  (None, 8, 8, 384)            1536      ['conv2d_173[0][0]']
#  atchNormalization)
#
#  conv2d_174 (Conv2D)         (None, 8, 8, 192)            393408    ['average_pooling2d_17[0][0]']
#
#  conv2d_175 (Conv2D)         (None, 8, 8, 320)            655680    ['concatenate_20[0][0]']
#
#  activation_169 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_169[0][0
#  )                                                                  ]']
#
#  activation_170 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_170[0][0
#  )                                                                  ]']
#
#  activation_172 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_172[0][0
#  )                                                                  ]']
#
#  activation_173 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_173[0][0
#  )                                                                  ]']
#
#  batch_normalization_174 (B  (None, 8, 8, 192)            768       ['conv2d_174[0][0]']
#  atchNormalization)
#
#  batch_normalization_175 (B  (None, 8, 8, 320)            1280      ['conv2d_175[0][0]']
#  atchNormalization)
#
#  concatenate_21 (Concatenat  (None, 8, 8, 768)            0         ['activation_169[0][0]',
#  e)                                                                  'activation_170[0][0]']
#
#  concatenate_22 (Concatenat  (None, 8, 8, 768)            0         ['activation_172[0][0]',
#  e)                                                                  'activation_173[0][0]']
#
#  activation_174 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_174[0][0
#  )                                                                  ]']
#
#  activation_175 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_175[0][0
#  )                                                                  ]']
#
#  concatenate_23 (Concatenat  (None, 8, 8, 2048)           0         ['concatenate_21[0][0]',
#  e)                                                                  'concatenate_22[0][0]',
#                                                                      'activation_174[0][0]',
#                                                                      'activation_175[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['concatenate_23[0][0]']
#  GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 2048)                 4196352   ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout_2 (Dropout)         (None, 2048)                 0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 1000)                 2049000   ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 27935112 (106.56 MB)
# Trainable params: 27900680 (106.43 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________
